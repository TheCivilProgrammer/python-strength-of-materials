# %% [markdown]
# <a href="https://colab.research.google.com/github/TheCivilProgrammer/python-strength-of-materials/blob/main/sample%20problems/Sample_Problem_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

# %%
class Force:
  def __init__(self, magnitude, direction):
    self.magnitude = magnitude
    # direction is in degrees counterclockwise from axis x
    self.direction = direction
    self.x, self.y = self.xy()

  def xy(self):
     x = self.magnitude * np.cos(np.radians(self.direction))
     y = self.magnitude * np.sin(np.radians(self.direction))
     return x, y

def get_resultant(list_of_forces):
  Rx = np.sum([force.x for force in list_of_forces])
  Ry = np.sum([force.y for force in list_of_forces])
  R = np.sqrt(np.square(Rx)+np.square(Ry))
  tan_alpha = Ry/Rx
  alpha = np.degrees(np.arctan(tan_alpha))
  return R, alpha

# %%
Q = Force(magnitude = 60, direction = 25 + 20)
P = Force(magnitude = 40, direction = 20)

# %%
list_of_forces = [Q, P]
get_resultant(list_of_forces)
# Out:
# (97.72552060631818, 35.03877088209511)
